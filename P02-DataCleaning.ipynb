# %% [markdown]
# # Practical - Data Pre-processing Part 2
# This practical session will demonstrate how to handle missing data. We assume everyone to have adequate understanding of Python programming language. For those who would like to refresh Python skill, we would like to recommend our <b>"Programming for Data Science Series"</b> where we covered almost all aspects of Python programming in data science domain.
# Refer below URL for full playlist of almost 10 hours video lesson in Burmese Language.
# URL : https://www.youtube.com/watch?v=jOZNjVVZIVs&list=PLD_eiqVVLZDi9GZZJDC8Zx4-3Np8LHs52

# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/myanmards/resource_files/master/sample-clean.csv')
data.head()
# Out:
#    emp_id birth_date first_name last_name gender hire_date  salary  height  \
# 0       1   02-09-53     Georgi   Facello      M  26-06-86  500000     165
# 1       2   02-06-64    Bezalel    Simmel      F  21-11-85  120000     155
# 2       3   03-12-59      Parto   Bamford      M  28-08-86  350000     158
# 3       4   01-05-54  Chirstian   Koblick      M  01-12-86  400000     149
# 4       5   21-01-55    Kyoichi  Maliniak      M  12-09-89  200000     169
#
#    weight  birth_place
# 0    64.0           NY
# 1    59.0      Chicago
# 2    75.0  Los Angeles
# 3    77.0  Los Angeles
# 4    74.0           LA

# %% [markdown]
# #### Simple featured scaling
# Normalize value is equal to old value divided by maximum value

# %%
data["height"] = data["height"]/data["height"].max()
data.head()
# Out:
#    emp_id birth_date first_name last_name gender hire_date  salary    height  \
# 0       1   02-09-53     Georgi   Facello      M  26-06-86  500000  0.846154
# 1       2   02-06-64    Bezalel    Simmel      F  21-11-85  120000  0.794872
# 2       3   03-12-59      Parto   Bamford      M  28-08-86  350000  0.810256
# 3       4   01-05-54  Chirstian   Koblick      M  01-12-86  400000  0.764103
# 4       5   21-01-55    Kyoichi  Maliniak      M  12-09-89  200000  0.866667
#
#    weight  birth_place
# 0    64.0           NY
# 1    59.0      Chicago
# 2    75.0  Los Angeles
# 3    77.0  Los Angeles
# 4    74.0           LA

# %% [markdown]
# #### Min-Max Normalization
# Normalize value is equal to old value minus minimum value divided by maximum value minus minimum value

# %%
data["weight"] = (data["weight"] - data["weight"].min()) / (data["weight"].max() - data["weight"].min())
data.head()
# Out:
#    emp_id birth_date first_name last_name gender hire_date  salary    height  \
# 0       1   02-09-53     Georgi   Facello      M  26-06-86  500000  0.846154
# 1       2   02-06-64    Bezalel    Simmel      F  21-11-85  120000  0.794872
# 2       3   03-12-59      Parto   Bamford      M  28-08-86  350000  0.810256
# 3       4   01-05-54  Chirstian   Koblick      M  01-12-86  400000  0.764103
# 4       5   21-01-55    Kyoichi  Maliniak      M  12-09-89  200000  0.866667
#
#     weight  birth_place
# 0  0.46875           NY
# 1  0.31250      Chicago
# 2  0.81250  Los Angeles
# 3  0.87500  Los Angeles
# 4  0.78125           LA

# %% [markdown]
# #### Z-score Normalization
# Normalize value is equal to old value minus mean value divided by standard deviation

# %%
data.describe()
# Out:
#            emp_id         salary      height     weight
# count  100.000000     100.000000  100.000000  78.000000
# mean    50.500000  325200.000000    0.858718   0.491987
# std     29.011492  193294.039894    0.046090   0.247473
# min      1.000000  120000.000000    0.764103   0.000000
# 25%     25.750000  200000.000000    0.820513   0.312500
# 50%     50.500000  300000.000000    0.861538   0.500000
# 75%     75.250000  400000.000000    0.888462   0.679688
# max    100.000000  750000.000000    1.000000   1.000000

# %%
data.mean()
# Out:
# emp_id        50.500000
# salary    325200.000000
# height         0.858718
# weight         0.491987
# dtype: float64

# %%
data.std()
# Out:
# emp_id        29.011492
# salary    193294.039894
# height         0.046090
# weight         0.247473
# dtype: float64

# %%
data["salary"] = (data["salary"] - data["salary"].mean()) /data["salary"].std()
data.head()
# Out:
#    emp_id birth_date first_name last_name gender hire_date    salary  \
# 0       1   02-09-53     Georgi   Facello      M  26-06-86  0.904322
# 1       2   02-06-64    Bezalel    Simmel      F  21-11-85 -1.061595
# 2       3   03-12-59      Parto   Bamford      M  28-08-86  0.128302
# 3       4   01-05-54  Chirstian   Koblick      M  01-12-86  0.386975
# 4       5   21-01-55    Kyoichi  Maliniak      M  12-09-89 -0.647718
#
#      height   weight  birth_place
# 0  0.846154  0.46875           NY
# 1  0.794872  0.31250      Chicago
# 2  0.810256  0.81250  Los Angeles
# 3  0.764103  0.87500  Los Angeles
# 4  0.866667  0.78125           LA

# %% [markdown]
# ### Converting

# %%
pd.get_dummies(data, columns=["gender"])
# Out:
#     emp_id birth_date   first_name     last_name hire_date    salary  \
# 0        1   02-09-53       Georgi       Facello  26-06-86  0.904322
# 1        2   02-06-64      Bezalel        Simmel  21-11-85 -1.061595
# 2        3   03-12-59        Parto       Bamford  28-08-86  0.128302
# 3        4   01-05-54    Chirstian       Koblick  01-12-86  0.386975
# 4        5   21-01-55      Kyoichi      Maliniak  12-09-89 -0.647718
# 92      93   11-06-64      Sailaja       Desikan  05-11-96  0.645648
# 93      94   25-05-57     Arumugam  Ossenbruggen  18-04-87 -0.906391
# 94      95   03-01-65       Hilari        Morton  15-07-86  2.197688
# 95      96   16-09-54       Jayson       Mandell  14-01-90  2.197688
# 96      97   27-02-52        Remzi   Waschkowski  15-09-90 -0.647718
# 97      98   23-09-61  Sreekrishna     Servieres  13-05-85  0.386975
# 98      99   25-05-56       Valter       Sullins  18-10-88 -0.647718
# 99     100   21-04-53     Hironobu     Haraldson  21-09-87 -0.130371
#
#       height   weight      birth_place  gender_F  gender_M
# 0   0.846154  0.46875               NY         0         1
# 1   0.794872  0.31250          Chicago         1         0
# 2   0.810256  0.81250      Los Angeles         0         1
# 3   0.764103  0.87500      Los Angeles         0         1
# 4   0.866667  0.78125               LA         0         1
# 5   0.830769      NaN          Houston         1         0
# 6   0.820513  0.40625          Chicago         1         0
# 7   0.815385  0.75000              WDC         0         1
# 8   0.887179  0.50000              WDC         1         0
# 9   0.825641      NaN  Washington D.C.         1         0
# 10  0.810256  0.12500      Los Angeles         1         0
# 11  0.861538  0.46875  Washington D.C.         0         1
# 12  0.866667  0.43750      Los Angeles         0         1
# 13  0.897436  0.50000          Chicago         0         1
# 14  0.825641  0.53125      Los Angeles         0         1
# 15  0.923077      NaN          Chicago         0         1
# 16  0.897436  0.09375              WDC         1         0
# 17  0.861538  0.53125              WDC         1         0
# 18  0.820513  0.68750      Los Angeles         0         1
# 19  0.866667  0.65625  Washington D.C.         0         1
# 20  0.861538  0.59375           Dallas         0         1
# 21  0.846154      NaN          Houston         0         1
# 22  0.810256  0.50000  Washington D.C.         1         0
# 23  0.825641  0.09375              WDC         1         0
# 24  0.846154  1.00000      Los Angeles         0         1
# 25  0.861538  0.87500              WDC         0         1
# 26  0.810256  0.06250         Atlanta          1         0
# 27  0.876923  0.31250          Houston         0         1
# 28  0.820513      NaN         Atlanta          0         1
# 29  0.846154  0.25000              WDC         0         1
# ..       ...      ...              ...       ...       ...
# 70  0.861538  0.18750           Dallas         0         1
# 71  0.825641  0.12500         New York         1         0
# 72  0.861538  0.25000         New York         0         1
# 73  0.912821      NaN          Chicago         1         0
# 74  0.815385  0.12500         New York         1         0
# 75  0.876923  0.09375               NY         1         0
# 76  0.887179  0.53125          Houston         0         1
# 77  0.830769  0.40625           Dallas         1         0
# 78  0.917949  0.75000          Houston         1         0
# 79  0.928205  0.50000          Chicago         0         1
# 80  0.897436  0.50000               NY         0         1
# 81  0.948718  0.12500               NY         0         1
# 82  0.953846  0.62500          Houston         0         1
# 83  0.933333  0.25000         New York         0         1
# 84  0.979487      NaN          Chicago         0         1
# 85  0.897436      NaN  Washington D.C.         0         1
# 86  0.815385  0.40625          Chicago         1         0
# 87  0.846154  0.50000  Washington D.C.         1         0
# 88  0.866667  0.18750         Atlanta          1         0
# 89  0.825641  0.12500         Atlanta          0         1
# 90  0.820513  0.78125  Washington D.C.         0         1
# 91  0.861538  0.59375         Atlanta          1         0
# 92  0.820513  0.75000               NY         0         1
# 93  0.810256  0.50000         Atlanta          1         0
# 94  0.892308  0.40625      Los Angeles         0         1
# 95  0.887179  0.28125               LA         0         1
# 96  0.876923      NaN          Chicago         0         1
# 97  0.810256  0.40625         New York         1         0
# 98  0.815385  0.75000          Houston         1         0
# 99  0.815385  0.50000  Washington D.C.         1         0
#
# [100 rows x 11 columns]

# %%
data.head()
# Out:
#    emp_id birth_date first_name last_name gender hire_date    salary  \
# 0       1   02-09-53     Georgi   Facello      M  26-06-86  0.904322
# 1       2   02-06-64    Bezalel    Simmel      F  21-11-85 -1.061595
# 2       3   03-12-59      Parto   Bamford      M  28-08-86  0.128302
# 3       4   01-05-54  Chirstian   Koblick      M  01-12-86  0.386975
# 4       5   21-01-55    Kyoichi  Maliniak      M  12-09-89 -0.647718
#
#      height   weight  birth_place
# 0  0.846154  0.46875           NY
# 1  0.794872  0.31250      Chicago
# 2  0.810256  0.81250  Los Angeles
# 3  0.764103  0.87500  Los Angeles
# 4  0.866667  0.78125           LA

# %%
data = pd.get_dummies(data, columns=['gender'])
data.head()
# Out:
#    emp_id birth_date first_name last_name hire_date    salary    height  \
# 0       1   02-09-53     Georgi   Facello  26-06-86  0.904322  0.846154
# 1       2   02-06-64    Bezalel    Simmel  21-11-85 -1.061595  0.794872
# 2       3   03-12-59      Parto   Bamford  28-08-86  0.128302  0.810256
# 3       4   01-05-54  Chirstian   Koblick  01-12-86  0.386975  0.764103
# 4       5   21-01-55    Kyoichi  Maliniak  12-09-89 -0.647718  0.866667
#
#     weight  birth_place  gender_F  gender_M
# 0  0.46875           NY         0         1
# 1  0.31250      Chicago         1         0
# 2  0.81250  Los Angeles         0         1
# 3  0.87500  Los Angeles         0         1
# 4  0.78125           LA         0         1

# %% [markdown]
# ### Discrete Binning

# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/myanmards/resource_files/master/sample-clean.csv')
data.head()
# Out:
#    emp_id birth_date first_name last_name gender hire_date  salary  height  \
# 0       1   02-09-53     Georgi   Facello      M  26-06-86  500000     165
# 1       2   02-06-64    Bezalel    Simmel      F  21-11-85  120000     155
# 2       3   03-12-59      Parto   Bamford      M  28-08-86  350000     158
# 3       4   01-05-54  Chirstian   Koblick      M  01-12-86  400000     149
# 4       5   21-01-55    Kyoichi  Maliniak      M  12-09-89  200000     169
#
#    weight  birth_place
# 0    64.0           NY
# 1    59.0      Chicago
# 2    75.0  Los Angeles
# 3    77.0  Los Angeles
# 4    74.0           LA

# %%
import numpy as np
bins = np.linspace(min(data["salary"]), max(data["salary"]), 6)
bins
# Out:
# array([120000., 246000., 372000., 498000., 624000., 750000.])

# %%
bin_names = ["Very Low", "Low", "Medium", "High", "Very High"]
data["salary-group"] = pd.cut(data["salary"], bins, labels=bin_names, include_lowest=True)

# %%
data.head(10)
# Out:
#    emp_id birth_date first_name  last_name gender hire_date  salary  height  \
# 0       1   02-09-53     Georgi    Facello      M  26-06-86  500000     165
# 1       2   02-06-64    Bezalel     Simmel      F  21-11-85  120000     155
# 2       3   03-12-59      Parto    Bamford      M  28-08-86  350000     158
# 3       4   01-05-54  Chirstian    Koblick      M  01-12-86  400000     149
# 4       5   21-01-55    Kyoichi   Maliniak      M  12-09-89  200000     169
# 5       6   20-04-53     Anneke    Preusig      F  02-06-89  300000     162
# 6       7   23-05-57    Tzvetan  Zielinski      F  10-02-89  150000     160
# 7       8   19-02-58     Saniya   Kalloufi      M  15-09-94  750000     159
# 8       9   19-04-52     Sumant       Peac      F  18-02-85  750000     173
# 9      10   01-06-63  Duangkaew   Piveteau      F  24-08-89  200000     161
#
#    weight      birth_place salary-group
# 0    64.0               NY         High
# 1    59.0          Chicago     Very Low
# 2    75.0      Los Angeles          Low
# 3    77.0      Los Angeles       Medium
# 4    74.0               LA     Very Low
# 5     NaN          Houston          Low
# 6    62.0          Chicago     Very Low
# 7    73.0              WDC    Very High
# 8    65.0              WDC    Very High
# 9     NaN  Washington D.C.     Very Low
